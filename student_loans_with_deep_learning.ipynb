# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
pip install keras_tuner
# Out:
# Collecting keras_tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (2.31.0)
# Collecting kt-legacy (from keras_tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (2024.7.4)
# Installing collected packages: kt-legacy, keras_tuner
# Successfully installed keras_tuner-1.4.7 kt-legacy-1.0.5

# %%
# Imports
import pandas as pd
import tensorflow as tf
import sklearn as skl
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               0
# 1                  9.8               0
# 2                  9.8               0
# 3                  9.8               1
# 4                  9.4               0

# %%
loans_df.sample(15).sort_values(by='credit_ranking')
# Out:
#       payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 1353              7.6               0.645               0.03          1.9
# 841               6.6               0.660               0.00          3.0
# 687               9.1               0.640               0.23          3.1
# 180               8.8               0.610               0.14          2.4
# 1009              9.6               0.500               0.36          2.8
# 705               8.4               1.035               0.15          6.0
# 814              12.6               0.410               0.54          2.8
# 948               8.9               0.120               0.45          1.8
# 70                7.7               0.630               0.08          1.9
# 776               6.9               0.765               0.18          2.4
# 549               9.0               0.530               0.49          1.9
# 1297              7.2               0.530               0.14          2.1
# 159               6.8               0.600               0.18          1.9
# 1209              6.2               0.390               0.43          2.0
# 1319              9.1               0.760               0.68          1.7
#
#       alumni_success  study_major_code  time_to_completion  \
# 1353           0.086              14.0                57.0
# 841            0.115              21.0                31.0
# 687            0.095              13.0                38.0
# 180            0.067              10.0                42.0
# 1009           0.116              26.0                55.0
# 705            0.073              11.0                54.0
# 814            0.103              19.0                41.0
# 948            0.075              10.0                21.0
# 70             0.076              15.0                27.0
# 776            0.243               5.5                48.0
# 549            0.171               6.0                25.0
# 1297           0.064              15.0                29.0
# 159            0.079              18.0                86.0
# 1209           0.071              14.0                24.0
# 1319           0.414              18.0                64.0
#
#       finance_workshop_score  cohort_ranking  total_loan_score  \
# 1353                 0.99690            3.37              0.46
# 841                  0.99629            3.45              0.63
# 687                  0.99980            3.28              0.59
# 180                  0.99690            3.19              0.59
# 1009                 0.99722            3.18              0.68
# 705                  0.99900            3.37              0.49
# 814                  0.99939            3.21              0.76
# 948                  0.99552            3.41              0.76
# 70                   0.99670            3.32              0.54
# 776                  0.99612            3.40              0.60
# 549                  0.99750            3.27              0.61
# 1297                 0.99323            3.35              0.61
# 159                  0.99680            3.59              0.57
# 1209                 0.99428            3.45              0.87
# 1319                 0.99652            2.90              1.33
#
#       financial_aid_score  credit_ranking
# 1353                 10.3               0
# 841                  10.3               0
# 687                   9.7               0
# 180                   9.5               0
# 1009                 10.9               0
# 705                   9.9               0
# 814                  11.3               1
# 948                  11.9               1
# 70                    9.5               1
# 776                  10.3               1
# 549                   9.4               1
# 1297                 12.1               1
# 159                   9.3               1
# 1209                 11.2               1
# 1319                  9.1               1

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df.copy()['credit_ranking']

# Display a sample of y
y.sample(10)
# Out:
# 1111    1
# 455     1
# 381     1
# 261     0
# 600     0
# 1239    0
# 1473    0
# 1076    1
# 785     0
# 997     1
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
x = loans_df.copy().drop(columns='credit_ranking')

# Review the features DataFrame
x.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score
# 0                  9.4
# 1                  9.8
# 2                  9.8
# 3                  9.8
# 4                  9.4

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
sc = skl.preprocessing.StandardScaler()

# Fit the scaler to the features training dataset
# Fit the scaler to the features training dataset
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=10,
        step=2), activation='relu', input_dim=len(x.columns)))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):

        # Declare hyperparams for this loop
        learn_rate = hp.Float(f'learn_rate_{i}', min_value=.1, max_value=.3, step=.1)
        layer_type_str = hp.Choice(f'layer_type_{i}',['Dense', 'Dropout', 'BatchNormalization'])
        activation = hp.Choice(f'activation_{i}',['relu','tanh','sigmoid'])
        units = hp.Int('units_' + str(i), min_value=1, max_value=10, step=2)

        nn_model_toadd = None
        match layer_type_str:
            case 'Dense':
                # Allow kerastuner to decide which activation function to use in hidden layers

                nn_model_toadd = tf.keras.layers.Dense(units=units,
                    activation=activation)
            case 'Dropout':
                nn_model_toadd = tf.keras.layers.Dropout(learn_rate)

            # case 'Embedding':
            #     nn_model_toadd = tf.keras.layers.Embedding(input_dim=input_dim, output_dim=output_dim)
            # removing Embedding as it is for Natural Language Processing: , 'Embedding'
            # input_dim = hp.Int('input_dim', min_value=50, max_value=100, step=2)
            # output_dim = hp.Int('output_dim', min_value=50, max_value=100, step=2)

            case 'BatchNormalization':
                nn_model_toadd = tf.keras.layers.BatchNormalization()

        nn_model.add(nn_model_toadd)

    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

    return nn_model

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=50,
    hyperband_iterations=50,
    overwrite=False,
    project_name='student_loans')

tuner.search(x_train, y_train, epochs=50, validation_data=(x_test, y_test))
# Out:
# Trial 1671 Complete [00h 00m 20s]
# val_accuracy: 0.7325000166893005
#
# Best val_accuracy So Far: 0.7649999856948853
# Total elapsed time: 04h 05m 10s
#
# Search: Running Trial #1672
#
# Value             |Best Value So Far |Hyperparameter
# 9                 |9                 |first_units
# 2                 |1                 |num_layers
# 0.1               |0.1               |learn_rate_0
# Dense             |Dense             |layer_type_0
# sigmoid           |tanh              |activation_0
# 3                 |3                 |units_0
# 0.2               |0.2               |learn_rate_1
# Dropout           |Dropout           |layer_type_1
# tanh              |relu              |activation_1
# 7                 |7                 |units_1
# 0.1               |0.2               |learn_rate_2
# Dropout           |Dense             |layer_type_2
# sigmoid           |sigmoid           |activation_2
# 1                 |9                 |units_2
# 0.2               |0.2               |learn_rate_3
# Dropout           |BatchNormalization|layer_type_3
# sigmoid           |sigmoid           |activation_3
# 5                 |3                 |units_3
# 0.1               |0.1               |learn_rate_4
# Dense             |Dense             |layer_type_4
# relu              |tanh              |activation_4
# 9                 |3                 |units_4
# 0.1               |0.2               |learn_rate_5
# Dense             |Dense             |layer_type_5
# sigmoid           |sigmoid           |activation_5
# 7                 |5                 |units_5
# 50                |50                |tuner/epochs
# 17                |17                |tuner/initial_epoch
# 3                 |2                 |tuner/bracket
# 3                 |2                 |tuner/round
# 1667              |0607              |tuner/trial_id
#
# Epoch 18/50
# 38/38 [==============================] - 1s 9ms/step - loss: 0.5576 - accuracy: 0.7431 - val_loss: 0.5743 - val_accuracy: 0.7125
# Epoch 19/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5510 - accuracy: 0.7306 - val_loss: 0.5731 - val_accuracy: 0.7125
# Epoch 20/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5551 - accuracy: 0.7198 - val_loss: 0.5708 - val_accuracy: 0.7100
# Epoch 21/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5527 - accuracy: 0.7398 - val_loss: 0.5694 - val_accuracy: 0.7125
# Epoch 22/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5410 - accuracy: 0.7423 - val_loss: 0.5669 - val_accuracy: 0.7125
# Epoch 23/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5477 - accuracy: 0.7323 - val_loss: 0.5661 - val_accuracy: 0.7125
# Epoch 24/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5508 - accuracy: 0.7339 - val_loss: 0.5647 - val_accuracy: 0.7125
# Epoch 25/50
# 38/38 [==============================] - 0s 6ms/step - loss: 0.5380 - accuracy: 0.7323 - val_loss: 0.5635 - val_accuracy: 0.7200
# Epoch 26/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5340 - accuracy: 0.7465 - val_loss: 0.5634 - val_accuracy: 0.7175
# Epoch 27/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5404 - accuracy: 0.7423 - val_loss: 0.5622 - val_accuracy: 0.7125
# Epoch 28/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5421 - accuracy: 0.7431 - val_loss: 0.5615 - val_accuracy: 0.7150
# Epoch 29/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5439 - accuracy: 0.7423 - val_loss: 0.5603 - val_accuracy: 0.7150
# Epoch 30/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5360 - accuracy: 0.7540 - val_loss: 0.5596 - val_accuracy: 0.7150
# Epoch 31/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5443 - accuracy: 0.7456 - val_loss: 0.5582 - val_accuracy: 0.7200
# Epoch 32/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5455 - accuracy: 0.7440 - val_loss: 0.5585 - val_accuracy: 0.7175
# Epoch 33/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5281 - accuracy: 0.7506 - val_loss: 0.5577 - val_accuracy: 0.7175
# Epoch 34/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5296 - accuracy: 0.7490 - val_loss: 0.5575 - val_accuracy: 0.7175
# Epoch 35/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5520 - accuracy: 0.7498 - val_loss: 0.5562 - val_accuracy: 0.7200
# Epoch 36/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5423 - accuracy: 0.7423 - val_loss: 0.5566 - val_accuracy: 0.7150
# Epoch 37/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5314 - accuracy: 0.7415 - val_loss: 0.5555 - val_accuracy: 0.7175
# Epoch 38/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5262 - accuracy: 0.7473 - val_loss: 0.5548 - val_accuracy: 0.7150
# Epoch 39/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5275 - accuracy: 0.7556 - val_loss: 0.5540 - val_accuracy: 0.7150
# Epoch 40/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5234 - accuracy: 0.7515 - val_loss: 0.5539 - val_accuracy: 0.7100
# Epoch 41/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5386 - accuracy: 0.7590 - val_loss: 0.5534 - val_accuracy: 0.7125
# Epoch 42/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5275 - accuracy: 0.7573 - val_loss: 0.5533 - val_accuracy: 0.7100
# Epoch 43/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5356 - accuracy: 0.7448 - val_loss: 0.5537 - val_accuracy: 0.7100
# Epoch 44/50
# 38/38 [==============================] - 0s 6ms/step - loss: 0.5283 - accuracy: 0.7498 - val_loss: 0.5523 - val_accuracy: 0.7100
# Epoch 45/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5198 - accuracy: 0.7690 - val_loss: 0.5522 - val_accuracy: 0.7100
# Epoch 46/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5285 - accuracy: 0.7573 - val_loss: 0.5509 - val_accuracy: 0.7150
# Epoch 47/50
# 38/38 [==============================] - 0s 6ms/step - loss: 0.5228 - accuracy: 0.7598 - val_loss: 0.5503 - val_accuracy: 0.7150
# Epoch 48/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5196 - accuracy: 0.7565 - val_loss: 0.5506 - val_accuracy: 0.7100
# Epoch 49/50
# 38/38 [==============================] - 0s 7ms/step - loss: 0.5283 - accuracy: 0.7590 - val_loss: 0.5503 - val_accuracy: 0.7225
# Epoch 50/50
# 38/38 [==============================] - 0s 6ms/step - loss: 0.5323 - accuracy: 0.7431 - val_loss: 0.5497 - val_accuracy: 0.7225
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-ba8708595554> in <cell line: 12>()
#      10     project_name='student_loans')
#      11
# ---> 12 tuner.search(x_train, y_train, epochs=50, validation_data=(x_test, y_test))
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     232
#     233             self.on_trial_begin(trial)
# --> 234             self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235             self.on_trial_end(trial)
#     236         self.on_search_end()
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py in _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272     def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273         try:
# --> 274             self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275             trial.status = trial_module.TrialStatus.COMPLETED
#     276             return
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py in _run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     237
#     238     def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239         results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240         if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241             self.oracle.objective.name
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/tuners/hyperband.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#     425             fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426             fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427         return super().run_trial(trial, *fit_args, **fit_kwargs)
#     428
#     429     def _build_hypermodel(self, hp):
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py in run_trial(self, trial, *args, **kwargs)
#     312             callbacks.append(model_checkpoint)
#     313             copied_kwargs["callbacks"] = callbacks
# --> 314             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     315
#     316             histories.append(obj_value)
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     231         hp = trial.hyperparameters
#     232         model = self._try_build(hp)
# --> 233         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     234
#     235         # Save the build config for model loading later.
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     147             If return a float, it should be the `objective` value.
#     148         """
# --> 149         return model.fit(*args, **kwargs)
#     150
#     151
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# KeyboardInterrupt:

# %%
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'first_units': 9,
#  'num_layers': 1,
#  'learn_rate_0': 0.1,
#  'layer_type_0': 'Dense',
#  'activation_0': 'tanh',
#  'units_0': 3,
#  'learn_rate_1': 0.2,
#  'layer_type_1': 'Dropout',
#  'activation_1': 'relu',
#  'units_1': 7,
#  'learn_rate_2': 0.2,
#  'layer_type_2': 'Dense',
#  'activation_2': 'sigmoid',
#  'units_2': 9,
#  'learn_rate_3': 0.2,
#  'layer_type_3': 'BatchNormalization',
#  'activation_3': 'sigmoid',
#  'units_3': 3,
#  'learn_rate_4': 0.1,
#  'layer_type_4': 'Dense',
#  'activation_4': 'tanh',
#  'units_4': 3,
#  'learn_rate_5': 0.2,
#  'layer_type_5': 'Dense',
#  'activation_5': 'sigmoid',
#  'units_5': 5,
#  'tuner/epochs': 50,
#  'tuner/initial_epoch': 17,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0607'}

# %% [markdown]
# {'first_units': 9,
#  'num_layers': 1,
#
#  'learn_rate_0': 0.1,
#  'layer_type_0': 'Dense',
#  'activation_0': 'tanh',
#  'units_0': 3,
#
#  'learn_rate_1': 0.2,
#  'layer_type_1': 'Dropout',
#  'activation_1': 'relu',
#  'units_1': 7,
#
#  'learn_rate_2': 0.2,
#  'layer_type_2': 'Dense',
#  'activation_2': 'sigmoid',
#  'units_2': 9,
#
#  'learn_rate_3': 0.2,
#  'layer_type_3': 'BatchNormalization',
#  'activation_3': 'sigmoid',
#  'units_3': 3,
#
#  'learn_rate_4': 0.1,
#  'layer_type_4': 'Dense',
#  'activation_4': 'tanh',
#  'units_4': 3,
#
#  'learn_rate_5': 0.2,
#  'layer_type_5': 'Dense',
#  'activation_5': 'sigmoid',
#  'units_5': 5,
#
#  Based on these results we should have 3 layers. A starting input layer, a single hidden layer, and an output layer
#
#  The hidden layers are what the tuning was for, which said to have just one as a Dense layer with tanh activation and 9 units

# %%
# Create the Sequential model instance
nn_model = tf.keras.models.Sequential()

# Review the number of features
input_nodes = len(x.columns)

# %%
# Define the number of hidden nodes for the first hidden layer
nn_model.add(tf.keras.layers.Dense(units=9, activation="relu", input_dim=input_nodes))
nn_model.add(tf.keras.layers.Dense(units=9, activation="tanh"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Display the Sequential model summary
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 9)                 108
#
#  dense_4 (Dense)             (None, 9)                 90
#
#  dense_5 (Dense)             (None, 1)                 10
#
# =================================================================
# Total params: 208 (832.00 Byte)
# Trainable params: 208 (832.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data

fit_model = nn_model.fit(x_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# 38/38 [==============================] - 1s 2ms/step - loss: 0.6461 - accuracy: 0.6230
# Epoch 2/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6092 - accuracy: 0.6764
# Epoch 3/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5815 - accuracy: 0.7056
# Epoch 4/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5594 - accuracy: 0.7248
# Epoch 5/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5416 - accuracy: 0.7356
# Epoch 6/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5290 - accuracy: 0.7448
# Epoch 7/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5208 - accuracy: 0.7515
# Epoch 8/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5147 - accuracy: 0.7606
# Epoch 9/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5103 - accuracy: 0.7573
# Epoch 10/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5068 - accuracy: 0.7615
# Epoch 11/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5036 - accuracy: 0.7631
# Epoch 12/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5018 - accuracy: 0.7615
# Epoch 13/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4998 - accuracy: 0.7656
# Epoch 14/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4979 - accuracy: 0.7640
# Epoch 15/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4969 - accuracy: 0.7665
# Epoch 16/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4956 - accuracy: 0.7673
# Epoch 17/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4946 - accuracy: 0.7640
# Epoch 18/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4932 - accuracy: 0.7698
# Epoch 19/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4923 - accuracy: 0.7690
# Epoch 20/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4901 - accuracy: 0.7706
# Epoch 21/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4894 - accuracy: 0.7706
# Epoch 22/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4883 - accuracy: 0.7706
# Epoch 23/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4869 - accuracy: 0.7715
# Epoch 24/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4861 - accuracy: 0.7715
# Epoch 25/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4853 - accuracy: 0.7731
# Epoch 26/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4839 - accuracy: 0.7690
# Epoch 27/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4828 - accuracy: 0.7731
# Epoch 28/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4818 - accuracy: 0.7706
# Epoch 29/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4812 - accuracy: 0.7723
# Epoch 30/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4797 - accuracy: 0.7740
# Epoch 31/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4786 - accuracy: 0.7765
# Epoch 32/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4783 - accuracy: 0.7765
# Epoch 33/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4773 - accuracy: 0.7798
# Epoch 34/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4769 - accuracy: 0.7765
# Epoch 35/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4750 - accuracy: 0.7748
# Epoch 36/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4747 - accuracy: 0.7781
# Epoch 37/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4732 - accuracy: 0.7807
# Epoch 38/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4722 - accuracy: 0.7815
# Epoch 39/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4720 - accuracy: 0.7807
# Epoch 40/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4707 - accuracy: 0.7823
# Epoch 41/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4700 - accuracy: 0.7807
# Epoch 42/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4692 - accuracy: 0.7815
# Epoch 43/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4678 - accuracy: 0.7823
# Epoch 44/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4674 - accuracy: 0.7832
# Epoch 45/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4662 - accuracy: 0.7807
# Epoch 46/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4653 - accuracy: 0.7815
# Epoch 47/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4644 - accuracy: 0.7815
# Epoch 48/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4638 - accuracy: 0.7790
# Epoch 49/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4626 - accuracy: 0.7823
# Epoch 50/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4632 - accuracy: 0.7865
# Epoch 51/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4613 - accuracy: 0.7840
# Epoch 52/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.7815
# Epoch 53/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4608 - accuracy: 0.7848
# Epoch 54/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4596 - accuracy: 0.7823
# Epoch 55/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4591 - accuracy: 0.7781
# Epoch 56/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4588 - accuracy: 0.7840
# Epoch 57/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4578 - accuracy: 0.7840
# Epoch 58/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4575 - accuracy: 0.7865
# Epoch 59/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4569 - accuracy: 0.7857
# Epoch 60/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4571 - accuracy: 0.7848
# Epoch 61/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4574 - accuracy: 0.7873
# Epoch 62/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4557 - accuracy: 0.7840
# Epoch 63/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4552 - accuracy: 0.7857
# Epoch 64/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4546 - accuracy: 0.7857
# Epoch 65/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4536 - accuracy: 0.7815
# Epoch 66/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4540 - accuracy: 0.7865
# Epoch 67/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4530 - accuracy: 0.7840
# Epoch 68/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4526 - accuracy: 0.7882
# Epoch 69/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4525 - accuracy: 0.7832
# Epoch 70/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4517 - accuracy: 0.7873
# Epoch 71/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4506 - accuracy: 0.7907
# Epoch 72/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4498 - accuracy: 0.7865
# Epoch 73/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4498 - accuracy: 0.7907
# Epoch 74/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4492 - accuracy: 0.7840
# Epoch 75/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4486 - accuracy: 0.7840
# Epoch 76/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4481 - accuracy: 0.7923
# Epoch 77/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4472 - accuracy: 0.7882
# Epoch 78/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4467 - accuracy: 0.7898
# Epoch 79/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4473 - accuracy: 0.7865
# Epoch 80/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4465 - accuracy: 0.7890
# Epoch 81/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4461 - accuracy: 0.7932
# Epoch 82/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4457 - accuracy: 0.7857
# Epoch 83/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4448 - accuracy: 0.7915
# Epoch 84/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4440 - accuracy: 0.7932
# Epoch 85/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4435 - accuracy: 0.7923
# Epoch 86/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4437 - accuracy: 0.7915
# Epoch 87/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4429 - accuracy: 0.7932
# Epoch 88/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4424 - accuracy: 0.7890
# Epoch 89/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4431 - accuracy: 0.7940
# Epoch 90/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4426 - accuracy: 0.7940
# Epoch 91/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4413 - accuracy: 0.7932
# Epoch 92/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4409 - accuracy: 0.7915
# Epoch 93/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4407 - accuracy: 0.7907
# Epoch 94/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4403 - accuracy: 0.7965
# Epoch 95/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4393 - accuracy: 0.7940
# Epoch 96/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4398 - accuracy: 0.7940
# Epoch 97/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4394 - accuracy: 0.7965
# Epoch 98/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4383 - accuracy: 0.7932
# Epoch 99/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4382 - accuracy: 0.7915
# Epoch 100/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4381 - accuracy: 0.7990
# Epoch 101/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4373 - accuracy: 0.7973
# Epoch 102/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4374 - accuracy: 0.7923
# Epoch 103/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4367 - accuracy: 0.7990
# Epoch 104/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4362 - accuracy: 0.7965
# Epoch 105/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4358 - accuracy: 0.7990
# Epoch 106/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4356 - accuracy: 0.8015
# Epoch 107/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4350 - accuracy: 0.7982
# Epoch 108/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4353 - accuracy: 0.7948
# Epoch 109/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4346 - accuracy: 0.8007
# Epoch 110/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4344 - accuracy: 0.7973
# Epoch 111/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4335 - accuracy: 0.8023
# Epoch 112/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4337 - accuracy: 0.8007
# Epoch 113/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4334 - accuracy: 0.8015
# Epoch 114/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4322 - accuracy: 0.7982
# Epoch 115/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4320 - accuracy: 0.7990
# Epoch 116/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4317 - accuracy: 0.8065
# Epoch 117/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4322 - accuracy: 0.7973
# Epoch 118/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4312 - accuracy: 0.8015
# Epoch 119/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4307 - accuracy: 0.8015
# Epoch 120/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4301 - accuracy: 0.8048
# Epoch 121/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4315 - accuracy: 0.7982
# Epoch 122/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4300 - accuracy: 0.8073
# Epoch 123/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4300 - accuracy: 0.8082
# Epoch 124/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4293 - accuracy: 0.8032
# Epoch 125/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4290 - accuracy: 0.8032
# Epoch 126/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4282 - accuracy: 0.8032
# Epoch 127/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4284 - accuracy: 0.8048
# Epoch 128/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4279 - accuracy: 0.8065
# Epoch 129/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4287 - accuracy: 0.8057
# Epoch 130/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4281 - accuracy: 0.8057
# Epoch 131/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4267 - accuracy: 0.8090
# Epoch 132/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4271 - accuracy: 0.8090
# Epoch 133/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4264 - accuracy: 0.8073
# Epoch 134/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4261 - accuracy: 0.8073
# Epoch 135/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4261 - accuracy: 0.8090
# Epoch 136/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4247 - accuracy: 0.8132
# Epoch 137/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4252 - accuracy: 0.8082
# Epoch 138/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4258 - accuracy: 0.8107
# Epoch 139/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4244 - accuracy: 0.8065
# Epoch 140/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4245 - accuracy: 0.8115
# Epoch 141/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4245 - accuracy: 0.8090
# Epoch 142/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4243 - accuracy: 0.8115
# Epoch 143/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4234 - accuracy: 0.8115
# Epoch 144/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4238 - accuracy: 0.8098
# Epoch 145/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4230 - accuracy: 0.8107
# Epoch 146/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4234 - accuracy: 0.8132
# Epoch 147/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4227 - accuracy: 0.8132
# Epoch 148/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4221 - accuracy: 0.8123
# Epoch 149/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4220 - accuracy: 0.8123
# Epoch 150/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4221 - accuracy: 0.8140
# Epoch 151/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4225 - accuracy: 0.8090
# Epoch 152/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4217 - accuracy: 0.8123
# Epoch 153/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4212 - accuracy: 0.8115
# Epoch 154/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4207 - accuracy: 0.8140
# Epoch 155/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4202 - accuracy: 0.8165
# Epoch 156/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4205 - accuracy: 0.8132
# Epoch 157/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4204 - accuracy: 0.8148
# Epoch 158/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4199 - accuracy: 0.8098
# Epoch 159/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4199 - accuracy: 0.8123
# Epoch 160/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4197 - accuracy: 0.8115
# Epoch 161/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4192 - accuracy: 0.8098
# Epoch 162/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4188 - accuracy: 0.8165
# Epoch 163/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4189 - accuracy: 0.8165
# Epoch 164/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4185 - accuracy: 0.8115
# Epoch 165/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4183 - accuracy: 0.8132
# Epoch 166/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4185 - accuracy: 0.8115
# Epoch 167/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4184 - accuracy: 0.8115
# Epoch 168/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4186 - accuracy: 0.8148
# Epoch 169/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4173 - accuracy: 0.8140
# Epoch 170/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4167 - accuracy: 0.8165
# Epoch 171/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4177 - accuracy: 0.8115
# Epoch 172/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4169 - accuracy: 0.8132
# Epoch 173/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4166 - accuracy: 0.8140
# Epoch 174/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4167 - accuracy: 0.8123
# Epoch 175/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4158 - accuracy: 0.8173
# Epoch 176/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4166 - accuracy: 0.8157
# Epoch 177/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4165 - accuracy: 0.8115
# Epoch 178/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4166 - accuracy: 0.8123
# Epoch 179/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4147 - accuracy: 0.8140
# Epoch 180/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4144 - accuracy: 0.8132
# Epoch 181/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4145 - accuracy: 0.8157
# Epoch 182/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4141 - accuracy: 0.8198
# Epoch 183/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4130 - accuracy: 0.8207
# Epoch 184/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4136 - accuracy: 0.8165
# Epoch 185/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4128 - accuracy: 0.8148
# Epoch 186/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4129 - accuracy: 0.8165
# Epoch 187/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4122 - accuracy: 0.8190
# Epoch 188/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4128 - accuracy: 0.8198
# Epoch 189/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4118 - accuracy: 0.8207
# Epoch 190/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4116 - accuracy: 0.8232
# Epoch 191/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4112 - accuracy: 0.8190
# Epoch 192/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4108 - accuracy: 0.8190
# Epoch 193/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4107 - accuracy: 0.8215
# Epoch 194/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4103 - accuracy: 0.8148
# Epoch 195/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4100 - accuracy: 0.8207
# Epoch 196/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4095 - accuracy: 0.8207
# Epoch 197/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4093 - accuracy: 0.8182
# Epoch 198/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4101 - accuracy: 0.8215
# Epoch 199/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.8190
# Epoch 200/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4090 - accuracy: 0.8207

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_model.evaluate(x_test, y_test, verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# given outputs:
# 13/13 - 0s - loss: 0.5049 - accuracy: 0.7350 - 175ms/epoch - 13ms/step
# Loss: 0.5049149394035339, Accuracy: 0.7350000143051147
# Out:
# 13/13 - 0s - loss: 0.5340 - accuracy: 0.7275 - 156ms/epoch - 12ms/step
# Loss: 0.5340055823326111, Accuracy: 0.7275000214576721

# %% [markdown]
# Based on the expected results, my accuracy is lower and my loss is higher. Perhaps I could have used the hyperparameter tuning to make this better but ran out of time to let it run, it ran for over 4 hours to get these results.
#
# I also had to adjust the tuning multiple times and rerun it, each giving different results.

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
from google.colab import drive
import pickle

# Set the model's file path
path = '/content/drive/' #dev/student loans/
filename = 'student_loans.keras'

# Export your model to a keras file
drive.mount(path)

# Export your model to a keras file
pickle.dump(nn_model, open(filename+'.pkl','wb'))
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
path
filename

# Load the model to a new object
model = pickle.load(open(filename+'.pkl','rb'))

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
pred = model.predict(x_test)

# Display a sample of the predictions
pred[:5]
# Out:
# 13/13 [==============================] - 0s 7ms/step
# array([[0.68860644],
#        [0.22568597],
#        [0.8684801 ],
#        [0.35793403],
#        [0.79996717]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
pred_df = pd.DataFrame(pred.round())

# Display a sample of the DataFrame
pred_df.head()
# Out:
#      0
# 0  1.0
# 1  0.0
# 2  1.0
# 3  0.0
# 4  1.0

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, pred_df))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.75      0.71       177
#            1       0.78      0.71      0.74       223
#
#     accuracy                           0.73       400
#    macro avg       0.73      0.73      0.73       400
# weighted avg       0.73      0.73      0.73       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
# We need more financial data. This seems to be class scores, even if the classes are related to finance it may not be a great predictor of how they manage their finances.
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
# Using context-based filtering makes the most sense, because based on the context of the students performance, we are determining their credit worthiness
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
# 1) Many students are young adults with not a lot of history / data about them to make a good prediction.
# 2) I believe student loans aren't paid until after they stop taking classes. I would expect re-payment is more based on the job they get, if they get one, after graduating. Which is information you won't have as they are going through school.
